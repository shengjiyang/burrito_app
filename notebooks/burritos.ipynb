# %%
import pandas as pd

df = pd.read_csv("data/burritos_01022018.csv")

print(df.shape)
df.head()
# Out:
# (385, 66)
#                Location      Burrito       Date Neighborhood  \
# 0    Donato's taco shop  California   1/18/2016      Miramar
# 1  Oscar's Mexican food  California   1/24/2016   San Marcos
# 2  Oscar's Mexican food     Carnitas  1/24/2016          NaN
# 3  Oscar's Mexican food  Carne asada  1/24/2016          NaN
# 4          Pollos Maria   California  1/27/2016     Carlsbad
#
#                     Address  \
# 0           6780 Miramar Rd
# 1  225 S Rancho Santa Fe Rd
# 2                       NaN
# 3                       NaN
# 4           3055 Harding St
#
#                                                  URL  Yelp  Google Chips  \
# 0                        http://donatostacoshop.net/   3.5     4.2   NaN
# 1  http://www.yelp.com/biz/oscars-mexican-food-sa...   3.5     3.3   NaN
# 2                                                NaN   NaN     NaN   NaN
# 3                                                NaN   NaN     NaN   NaN
# ...

# %%
df.columns
# Out:
# Index(['Location', 'Burrito', 'Date', 'Neighborhood', 'Address', 'URL', 'Yelp',
#        'Google', 'Chips', 'Cost', 'Hunger', 'Mass (g)', 'Density (g/mL)',
#        'Length', 'Circum', 'Volume', 'Tortilla', 'Temp', 'Meat', 'Fillings',
#        'Meat:filling', 'Uniformity', 'Salsa', 'Synergy', 'Wrap', 'overall',
#        'Rec', 'Reviewer', 'Notes', 'Unreliable', 'NonSD', 'Beef', 'Pico',
#        'Guac', 'Cheese', 'Fries', 'Sour cream', 'Pork', 'Chicken', 'Shrimp',
#        'Fish', 'Rice', 'Beans', 'Lettuce', 'Tomato', 'Bell peper', 'Carrots',
#        'Cabbage', 'Sauce', 'Salsa.1', 'Cilantro', 'Onion', 'Taquito',
#        'Pineapple', 'Ham', 'Chile relleno', 'Nopales', 'Lobster', 'Queso',
#        'Egg', 'Mushroom', 'Bacon', 'Sushi', 'Avocado', 'Corn', 'Zucchini'],
#       dtype='object')

# %%
count = df.Burrito.value_counts().sort_values(ascending=True)
count
# Out:
# Adobado             1
# Oaxacalifornia      1
# Bean and Cheese     1
# Surf and Turf       1
# Golden State        1
#                    ..
# Surf & Turf        15
# Carnitas           17
# California         26
# Carne asada        27
# California         91
# Name: Burrito, Length: 123, dtype: int64

# %%
types = list(count.to_dict().keys())
types
# Out:
# ['Adobado',
#  'Oaxacalifornia',
#  'Bean and Cheese',
#  'Surf and Turf',
#  'Golden State',
#  'Shrimp with guac',
#  'Al Pastor',
#  'Bean & cheese',
#  'Chicken and rice',
#  'battered fish ',
#  'Quesa',
#  'Steak fajitas',
#  'Azteca',
#  'Quesaburro',
#  'Combo chicken',
#  'California breakfast',
#  'Lobster',
#  'Arizona',
#  'Especial ',
#  'Cabeza',
#  "Deborah's special",
#  'El Hawaiiano ',
#  'Chicken avocado',
#  'Chicken Shawarma',
#  'Cheese steak',
#  'Al pastor ',
#  'Chicken asada',
#  'Steak everything ',
#  'California Chipotle',
#  'Hawaiian',
#  'Fajitas ',
#  'Pork california',
#  'Cali Diablo',
#  'Bean and rice grande size',
#  'Steak with guacamole',
#  'Surf and turf',
#  'Chimichanga beef',
#  'Tijuana',
#  'Shrimp california',
#  'Mixed',
#  'Chile relleno and carnitas',
#  'California + Guac + sour cream',
#  'Vegetarian',
#  'Carne asada supreme',
#  'El Rusio',
#  'California everything mini',
#  'Bitchin California',
#  'Hot cheetos',
#  'Nutty',
# ...

# %%
import matplotlib.pyplot as plt

f, ax = plt.subplots(figsize=(20, 17))

plt.barh(types, count.to_list());

# %%
print("NaN Counts")
print("----------\n")

for col in df.columns:
    print(col)
    print("-----------")
    print(df[col].isna().sum())
# Out:
# NaN Counts
# ----------
#
# Location
# -----------
# 0
# Burrito
# -----------
# 0
# Date
# -----------
# 0
# Neighborhood
# -----------
# 298
# Address
# -----------
# 302
# URL
# -----------
# 303
# Yelp
# -----------
# 303
# Google
# -----------
# 303
# Chips
# -----------
# 361
# Cost
# -----------
# 7
# Hunger
# -----------
# 3
# Mass (g)
# -----------
# 363
# Density (g/mL)
# -----------
# 363
# Length
# -----------
# 134
# Circum
# -----------
# 136
# Volume
# -----------
# 136
# Tortilla
# -----------
# 0
# Temp
# -----------
# 20
# Meat
# -----------
# 12
# Fillings
# -----------
# 2
# Meat:filling
# -----------
# 8
# Uniformity
# -----------
# 2
# Salsa
# -----------
# 22
# Synergy
# -----------
# 2
# Wrap
# -----------
# 2
# overall
# -----------
# 2
# Rec
# -----------
# 157
# Reviewer
# -----------
# 1
# Notes
# -----------
# 256
# Unreliable
# -----------
# 355
# NonSD
# -----------
# 378
# Beef
# -----------
# 209
# Pico
# -----------
# 233
# Guac
# -----------
# 238
# ...

# %%
simplified = df[["Volume", "Tortilla", "Temp", "Meat", "Fillings", "Meat:filling", "Uniformity", "Salsa", "Synergy", "Wrap"]]

print(simplified.shape)
simplified.head()
# Out:
# (385, 10)
#    Volume  Tortilla  Temp  Meat  Fillings  Meat:filling  Uniformity  Salsa  \
# 0     NaN       3.0   5.0   3.0       3.5           4.0         4.0    4.0
# 1     NaN       2.0   3.5   2.5       2.5           2.0         4.0    3.5
# 2     NaN       3.0   2.0   2.5       3.0           4.5         4.0    3.0
# 3     NaN       3.0   2.0   3.5       3.0           4.0         5.0    4.0
# 4     NaN       4.0   5.0   4.0       3.5           4.5         5.0    2.5
#
#    Synergy  Wrap
# 0      4.0   4.0
# 1      2.5   5.0
# 2      3.0   5.0
# 3      4.0   5.0
# 4      4.5   4.0

# %%
simplified.Volume.describe()
# Out:
# count    249.000000
# mean       0.785462
# std        0.153465
# min        0.400000
# 25%        0.680000
# 50%        0.770000
# 75%        0.880000
# max        1.540000
# Name: Volume, dtype: float64

# %%
import numpy as np

avg_vol = simplified.Volume.describe().to_dict()["mean"]

for i in range(len(df.Volume.values)):
    if df.Volume[i] == np.nan:
        df.Volume[i] = avg_vol
# Out:
# nan

# %%
df.Rec
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 380    NaN
# 381    NaN
# 382    NaN
# 383    NaN
# 384    NaN
# Name: Rec, Length: 385, dtype: object

# %%
df.NonSD
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 380    NaN
# 381    NaN
# 382      x
# 383    NaN
# 384    NaN
# Name: NonSD, Length: 385, dtype: object
